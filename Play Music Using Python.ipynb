# %% [markdown]
# ![R.jpeg](attachment:R.jpeg)

# %%
from playsound import playsound
filename=input("Enter nusic file name :")
print("Playing music {}.....🎵".format(filename))
playsound(filename)
print("Song Ended")
# Out:
# Enter nusic file name :Jo Tenu Dhoop Lagya Ve.mp3
# Playing music Jo Tenu Dhoop Lagya Ve.mp3.....🎵
# Song Ended

# %% [markdown]
# **Note:mp3 file must present at the same location where .py or .ipynb file located**
